# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img
# Out:
# Using TensorFlow backend.

# %%
datagen = ImageDataGenerator(
    rotation_range=60,
    horizontal_flip=True,
    zoom_range=0.4,
    width_shift_range=0.2,
    height_shift_range=0.5,
    shear_range=0.3
    
)

# %%
img = load_img("C:\\Data\\img Aug\\car2.jpeg")  # this is a PIL imag
print(img.size)
# Out:
# (540, 306)

# %%
# converting image to array
x=img_to_array(img) #  is is a Numpy array with shape (306, 540, 3)

# %%
x.shape
# Out:
# (306, 540, 3)

# %%
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 306, 540, 3)
print(x.shape)
# Out:
# (1, 306, 540, 3)

# %%
#Flow will continually generate
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
# %matplotlib inline
from numpy import expand_dims
i=0
for batch in datagen.flow(x, batch_size=1, save_to_dir='.', save_format='jpeg'):
     i+=1
     
     if i > 20:
        break

# %%
pwd
# Out:
# 'C:\\Data\\img Aug'

# %%
# load the image
img = load_img("C:\\Data\\img Aug\\car2.jpeg")
# convert to numpy array
data = img_to_array(img)
print(img.size)
# expand dimension to one sample
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(
    rotation_range=60,
    horizontal_flip=True,
    zoom_range=0.4,
    width_shift_range=0.2,
    height_shift_range=0.
    
)
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(10):
    # define subplot
    plt.subplot(5,2, 1 + i)
    # generate batch of images
    batch = it.next()
    # convert to unsigned integers for viewing
    image = batch[0].astype('uint8')
    # plot raw pixel data
    plt.imshow(image)
# show the figure
plt.show()
# Out:
# (540, 306)

# %%
from albumentations import (
    HorizontalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, IAAPiecewiseAffine,
    IAASharpen, IAAEmboss, RandomBrightnessContrast, Flip, OneOf, Compose
)
import numpy as np
import cv2

# %%
image = cv2.imread("C:\\Data\\img Aug\\car2.jpeg", cv2.IMREAD_COLOR)
plt.imshow(image)

# %%
import albumentations as A
import imageio
rect = patches.Rectangle((10,10,), 510, 290,linewidth=1,edgecolor='r',facecolor='none')
# Initialize an augmentation
blur=A.Blur(blur_limit=(10, 50), p=1)
# Apply augmentation

img_blur= blur(image=image, bboxes =rect)
# Access the augmented image by the 'image' key

img_aug_blur=img_blur['image']
bbox_aug= img_blur['bboxes']
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(img_aug_blur)
plt.imshow(img_aug_blur)
ax.add_patch(bbox_aug)
plt.show()

# %%
dist=A.MultiplicativeNoise(multiplier=0.5, p=1)
# Apply augmentation

img_dist= dist(image=image)
# Access the augmented image by the 'image' key

img_aug=img_dist['image']

fig,ax = plt.subplots(1)

# Display the image
ax.imshow(img_aug)

plt.show()

# %%
image = cv2.imread("C:\\Data\\img Aug\\car2.jpeg", cv2.IMREAD_COLOR)
rect = patches.Rectangle((10,10,), 510, 290,linewidth=1,edgecolor='r',facecolor='none')
bbs = [(10, 520, 10, 300)]

# Initialize an augmentation
crop= A.CenterCrop(p=1, height=300, width=300)
# Apply augmentation

img_blur= crop(image=image,bboxes=bbs )
# Access the augmented image by the 'image' key

img_aug_blur=img_blur['image']
bbox_aug= img_blur['bboxes']
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(img_aug_blur)
#ax.imshow(bbox_aug)

plt.show()

# %%
image = cv2.imread("C:\\Data\\img Aug\\car2.jpeg", cv2.IMREAD_COLOR)
rect = patches.Rectangle((10,10,), 510, 290,linewidth=1,edgecolor='r',facecolor='none')
bbs = [(10, 520, 10, 300)]
cv2.rectangle(image, (10, 10), (510, 290), color='r', thickness=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-d6730606414f> in <module>
#       2 rect = patches.Rectangle((10,10,), 510, 290,linewidth=1,edgecolor='r',facecolor='none')
#       3 bbs = [(10, 520, 10, 300)]
# ----> 4 cv2.rectangle(image, (10, 10), (510, 290), color='r', thickness=2)
#
# TypeError: argument for rectangle() given by name ('color') and position (3)
